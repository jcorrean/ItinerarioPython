# %% [markdown]
# # Bienvenido a tu primer Jupyter
#
# Este archivo tiene el propósito de enseñarte algunas funcionalidades básicas de un cuaderno jupyter (Jupyter Notebook). La primera funcionalidad es mostrarte cómo se puede abrir un archivo de datos separados por comas (archivo .csv).

# %% [markdown]
# Para trabajar este archivo en Google Colab, simplemente entramos a esta [url](https://colab.research.google.com/)

# %%
import pandas as pd
datos = pd.read_csv("newdata.csv")
datos.head()
# Out:
#     Moment  number                                                web  \
# 0  Morning       1  https://domicilios.com/bogota/kfc-cc-atlantis-...
# 1  Morning       1  https://domicilios.com/bogota/kfc-cc-atlantis-...
# 2  Morning       1  https://domicilios.com/bogota/kfc-cc-atlantis-...
# 3  Morning       1  https://domicilios.com/bogota/kfc-cc-atlantis-...
# 4  Morning       1  https://domicilios.com/bogota/kfc-cc-atlantis-...
#
#   Name of Provider Number of Comments  Expected Delivery Time  \
# 0             KFC                5329                    45.0
# 1             KFC                5329                    45.0
# 2             KFC                5329                    45.0
# 3             KFC                5329                    45.0
# 4             KFC                5329                    45.0
#
#    Minimum Charge Ordering  Cost Delivery  Latitude  Longitude  \
# 0                   9900.0         3500.0   4.66597  -74.05558
# 1                   9900.0         3500.0   4.66597  -74.05558
# 2                   9900.0         3500.0   4.66597  -74.05558
# 3                   9900.0         3500.0   4.66597  -74.05558
# 4                   9900.0         3500.0   4.66597  -74.05558
#
#   Typical Traffic Afternoon Typical Traffic Noon Typical Traffic Morning  \
# 0                       Red               Orange                   Green
# 1                       Red               Orange                   Green
# 2                       Red               Orange                   Green
# 3                       Red               Orange                   Green
# 4                       Red               Orange                   Green
#
#   DailyTraffic  ClientLatitude  ClientLongitude  Distance(mts)  Time(sec)  \
# 0          ROG        4.665798       -74.040855           2500        660
# 1          ROG        4.666159       -74.038331           3300        720
# 2          ROG        4.670228       -74.026783           9100       1740
# 3          ROG        4.662140       -74.008008           9700       1740
# 4          ROG        4.669905       -74.104917           8800       1320
#
#    Time(min)
# 0         11
# 1         12
# 2         29
# 3         29
# 4         22

# %%
datos.describe()
# Out:
#              number  Expected Delivery Time  Minimum Charge Ordering  \
# count  19934.000000            18534.000000             16906.000000
# mean     418.140815               44.591777             13050.040222
# std      243.022426               12.611571             11678.566928
# min        1.000000                5.000000                45.000000
# 25%      209.000000               40.000000              9900.000000
# 50%      416.000000               45.000000             10000.000000
# 75%      624.000000               45.000000             15000.000000
# max      871.000000               90.000000            260000.000000
#
#        Cost Delivery      Latitude     Longitude  ClientLatitude  \
# count   14271.000000  19934.000000  19934.000000    19934.000000
# mean     2614.453928      4.676505    -74.071316        4.676490
# std      1577.961057      0.043787      0.031818        0.043889
# min         0.000000      4.470490    -74.221359        4.466902
# 25%      2000.000000      4.646707    -74.089158        4.647090
# 50%      2800.000000      4.677227    -74.061433        4.677056
# 75%      3500.000000      4.709429    -74.049650        4.708853
# max     20000.000000      4.776851    -74.022591        4.781545
#
#        ClientLongitude  Distance(mts)     Time(sec)     Time(min)
# count     19934.000000   19934.000000  19934.000000  19934.000000
# mean        -74.071243    8545.049814   1263.124310     21.052072
# std           0.053169    6071.839900    805.202737     13.420046
# min         -74.290032      12.000000     60.000000      1.000000
# 25%         -74.108246    3700.000000    660.000000     11.000000
# 50%         -74.070791    7500.000000   1140.000000     19.000000
# 75%         -74.030337   11800.000000   1680.000000     28.000000
# max         -73.949349   54400.000000   3540.000000     59.000000
