# %% [markdown]
# # Web Scraping (para una lista sencilla de carros a la venta en OLX)
#
# En este cuaderno aprenderás cómo se usa Python para aplicar web scraping como herramienta de extracción automática de data disponible en mercadolibre.com.
#
# En este caso, nos concentraremos en OLX.com (Colombia) y en la categoría [carros](https://www.olx.com.co/carros_c378). Al momento de documentar este cuaderno, el resultado que obtuvimos al visitar esa página fue semejante a la siguiente ![esta imagen](carros.png)
#
# La idea es "transformar" esa lista de celulares, con la info de su descripción y precio a una tabla de datos estructurada como la que estudiamos en un cuaderno anterior. Para este cuaderno necesitamos instalar una nueva librería llamada selenium. Para instalarla, solo debes quitar el simbolo de hashtag (#) que aparece en la siguiente celda y correrla.

# %%
# pip install selenium

# %%
from selenium import webdriver

driver = webdriver.Chrome('/usr/bin/firefox')
dirver.get('https://www.olx.com.co/carros_c378')

carros = driver.find_elements_by_xpath('//li[@data-aut-id="itemBox"]')

for carros in carros:
    precio = carros.find_element_by_xpath('.//span[@data-aut-id="itemPrice"]').text
    print(precio)
    descripcion = auto.find_element_by_xpath('.//span[@data-aut-id="itemTitle"]').text
    print(descripcion)
# Out:
# /tmp/ipykernel_82349/2534119407.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('/usr/bin/firefox')
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# /tmp/ipykernel_82349/2534119407.py in <module>
#       1 from selenium import webdriver
#       2
# ----> 3 driver = webdriver.Chrome('/usr/bin/firefox')
#       4 dirver.get('https://www.olx.com.co/carros_c378')
#       5
#
# ~/anaconda3/lib/python3.9/site-packages/selenium/webdriver/chrome/webdriver.py in __init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, service, keep_alive)
#      68             service = Service(executable_path, port, service_args, service_log_path)
#      69
# ---> 70         super(WebDriver, self).__init__(DesiredCapabilities.CHROME['browserName'], "goog",
# ...
