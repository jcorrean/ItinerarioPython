# %% [markdown]
# # Web Scraping (para una lista sencilla en mercadolibre)
#
# En este cuaderno aprenderás cómo se usa Python para aplicar web scraping como herramienta de extracción automática de data disponible en mercadolibre.com.
#
# En este caso, nos concentraremos en mercadolibre.com (Colombia) y en la categoría [teléfonos celulares](https://celulares.mercadolibre.com.co/#menu=categories). Al momento de documentar este cuaderno, el resultado que obtuvimos al visitar esa página fue semejante al de ![esta imagen]("img/picture.png")
