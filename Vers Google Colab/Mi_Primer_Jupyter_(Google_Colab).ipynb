# %% [markdown]
# # Bienvenido a tu primer Jupyter - Version Google Colab
#
# Este archivo tiene el propósito de enseñarte algunas funcionalidades básicas de un cuaderno jupyter (Jupyter Notebook). La primera funcionalidad es mostrarte cómo se puede abrir un archivo de datos separados por comas (archivo .csv).

# %% [markdown]
# ## 1. Conexion al Repositorio de Github
# Debes conectarte al repositiorio para tener acceso a los datos de la actividad.

# %%
url = "https://raw.githubusercontent.com/jcorrean/ItinerarioPython/main/newdata.csv"   # Link del repositorio Github de datos

# %% [markdown]
# ## 2. Llamado a las librerias
# Siempre debes asegurarte de llamar las librerias necesarias para el desarrollo de tus actividades, de tal forma que no te generen errores o inconsistencias en pasos posteriores

# %%
import pandas as pd                     # Libreria especializada en el manejo y estructura de datos

# %% [markdown]
# ## 3. Conjunto de datos o datasets a utilizar
# Debes indicar los conjuntos de datos o datasets que contienen la informacion que analizaras en tu actividad.
# Se cuidadoso de incluir toda la ruta donde se encuentra el archivo, así como la extensión del mismo. Recuerda que en este caso de trata de un archivo csv o de datos separados por comas.
# Es conveniente que te acostumbres a validar que los datos se hayan leido correctamente, mediante comandos como head() o tail() y vaerificar la cantidad de datos leidos con len.

# %%
datos = pd.read_csv("newdata.csv")      # En datos se guardara la informacion del archivo de datos "newdata.csv"

# %%
datos.head()                            # Muestra el contenido de los cinco primeros registros del dataframe "datos"
# Out:
#     Moment  number                                                web  \
# 0  Morning       1  https://domicilios.com/bogota/kfc-cc-atlantis-...
# 1  Morning       1  https://domicilios.com/bogota/kfc-cc-atlantis-...
# 2  Morning       1  https://domicilios.com/bogota/kfc-cc-atlantis-...
# 3  Morning       1  https://domicilios.com/bogota/kfc-cc-atlantis-...
# 4  Morning       1  https://domicilios.com/bogota/kfc-cc-atlantis-...
#
#   Name of Provider  Number of Comments  Expected Delivery Time  \
# 0             KFC               5329.0                    45.0
# 1             KFC               5329.0                    45.0
# 2             KFC               5329.0                    45.0
# 3             KFC               5329.0                    45.0
# 4             KFC               5329.0                    45.0
#
#    Minimum Charge Ordering  Cost Delivery  Latitude  Longitude  \
# 0                   9900.0         3500.0   4.66597  -74.05558
# ...

# %%
datos.tail()                            # Muestra el contenido de los ultimos cinco registros del dataframe "datos"
# Out:
#           Moment  number                                                web  \
# 19929  Afternoon     752  https://domicilios.com/bogota/a-mordiscos-2.ht...
# 19930  Afternoon     752  https://domicilios.com/bogota/a-mordiscos-2.ht...
# 19931  Afternoon     752  https://domicilios.com/bogota/a-mordiscos-2.ht...
# 19932  Afternoon     752  https://domicilios.com/bogota/a-mordiscos-2.ht...
# 19933  Afternoon     752  https://domicilios.com/bogota/a-mordiscos-2.ht...
#
#       Name of Provider  Number of Comments  Expected Delivery Time  \
# 19929     A Mordiscos                  0.0                    45.0
# 19930     A Mordiscos                  0.0                    45.0
# 19931     A Mordiscos                  0.0                    45.0
# 19932     A Mordiscos                  0.0                    45.0
# 19933     A Mordiscos                  0.0                    45.0
#
#        Minimum Charge Ordering  Cost Delivery  Latitude   Longitude  \
# ...

# %%
print(len(datos))
# Out:
# 19934

# %% [markdown]
# ## 4. Caracteristicas generales de conjunto de datos
# Comprender las caracteristicas de los datos es fundamental para su interpretación. Valores como la media, el minimo, el maximo y la desviacion entre otros son esenciales para lograr el entendimiento del comportmiento de los datos.

# %%
datos.describe()                         # Muestra las principales estadisticas descriptivas de los datos numericos del dataframe "datos"
# Out:
#              number  Number of Comments  Expected Delivery Time  \
# count  19934.000000        14727.000000            18558.000000
# mean     418.140815          200.618795               44.592305
# std      243.022426          794.873828               12.603421
# min        1.000000            0.000000                5.000000
# 25%      209.000000            3.000000               40.000000
# 50%      416.000000           26.000000               45.000000
# 75%      624.000000          139.000000               45.000000
# max      871.000000        12832.000000               90.000000
#
#        Minimum Charge Ordering  Cost Delivery      Latitude  ClientLatitude  \
# count             16906.000000   14271.000000  19934.000000    19934.000000
# mean              13078.368627    2580.827116      4.581730        4.581726
# std               11671.185974    1411.358955      2.730836        2.730568
# min                2000.000000       0.000000    -74.061067      -74.134704
# ...
